# %% [markdown]
# # CNN Example FromFile by Keras (Color Version)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
from tensorflow.keras import datasets, layers, models, regularizers

import numpy as np
import matplotlib.pyplot as plt

# %%
from os import listdir
from os.path import isfile, join
from pylab import *
from numpy import *

def getFolder(thePath,isFile=True):
    return [f for f in listdir(thePath) if isFile == isfile(join(thePath, f)) ]


def getImagesAndLabels(tPath):
    labels=getFolder(tPath,False)
    encoder={w: i for i, w in enumerate(labels)}
    decoder={i: w  for i, w in enumerate(labels)}

    
    tImages,tLabels=None,None

    for label in labels:
        imgFolder=join(tPath,label)
        files= [f for f in listdir(imgFolder) if isfile(join(imgFolder, f))]
        for file in files:
            imageFile=join(imgFolder,file)
            img=np.array([imread(imageFile)])/255.
            if tImages is None:
                tImages, tLabels =img, np.array([encoder[label]],ndmin=1)
            else:
#                 print(tImages.shape,img.shape,imageFile)
                tImages = np.vstack( (tImages,img) )
                tLabels = np.append(tLabels,np.array([encoder[label]]) ,axis=0) 
        print(label,tImages.shape)                 
    return (tImages,tLabels,encoder,decoder)

# %%
from sklearn.model_selection import train_test_split
basePath='../../data/flower_photos_300x200_small'
imgs,labels,encoder,decoder=getImagesAndLabels(basePath)

class_cnt=len(encoder.keys())

train_images,test_images,train_labels,test_labels=train_test_split(imgs,labels,test_size=0.3333, random_state=99)
# Out:
# daisy (100, 200, 300, 3)
# tulips (200, 200, 300, 3)

# %%
imgShape=train_images[0].shape
img_width,img_hight,color_count=imgShape
train_images = train_images.reshape((-1,img_width,img_hight,color_count ))
test_images = test_images.reshape((-1, img_width,img_hight,color_count ))

print("Shape of Train_images = ",train_images.shape)
# Out:
# Shape of Train_images =  (133, 200, 300, 3)

# %%
model = models.Sequential()
model.add(layers.Conv2D(128, (9, 9), activation='relu',padding='same',kernel_regularizer=regularizers.l2(0.05), input_shape=imgShape))
model.add(layers.Dropout(0.2))
model.add(layers.MaxPooling2D((4, 4)))

model.add(layers.Conv2D(64, (3, 3), activation='relu',padding='same',kernel_regularizer=regularizers.l2(0.05)))
model.add(layers.Dropout(0.2))
model.add(layers.MaxPooling2D((2, 2)))


model.add(layers.Flatten())
model.add(layers.Dense(96, activation='sigmoid',kernel_regularizer=regularizers.l2(0.05)))
model.add(layers.Dense(class_cnt, activation='softmax'))
# model.summary()

# %%
from tensorflow.python.keras.optimizers import Adam
model.compile(optimizer=Adam(lr=0.0002, beta_1=0.99, beta_2=0.9999),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_images, train_labels, epochs=200,batch_size=20)
# Out:
# Train on 133 samples
# Epoch 1/200
# 133/133 [==============================] - 2s 14ms/sample - loss: 1.2353 - acc: 0.7519
# Epoch 2/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.8476 - acc: 0.8120
# Epoch 3/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.8593 - acc: 0.7970
# Epoch 4/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.7870 - acc: 0.8571
# Epoch 5/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.7773 - acc: 0.8496
# Epoch 6/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.7322 - acc: 0.9023
# Epoch 7/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.7265 - acc: 0.9098
# Epoch 8/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.6874 - acc: 0.9098
# Epoch 9/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.6721 - acc: 0.9098
# Epoch 10/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.6322 - acc: 0.9549
# Epoch 11/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.6141 - acc: 0.9474
# Epoch 12/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.6023 - acc: 0.9323
# Epoch 13/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5773 - acc: 0.9699
# Epoch 14/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5615 - acc: 0.9699
# Epoch 15/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5636 - acc: 0.9549
# Epoch 16/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5863 - acc: 0.9173
# Epoch 17/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5954 - acc: 0.9474
# Epoch 18/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5607 - acc: 0.9248
# Epoch 19/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5355 - acc: 0.9474
# Epoch 20/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.5511 - acc: 0.9173
# Epoch 21/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4944 - acc: 0.9774
# Epoch 22/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4849 - acc: 0.9850
# Epoch 23/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4727 - acc: 0.9850
# Epoch 24/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4609 - acc: 0.9925
# Epoch 25/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4546 - acc: 0.9925
# Epoch 26/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4434 - acc: 0.9925
# Epoch 27/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4309 - acc: 0.9925
# Epoch 28/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4249 - acc: 1.0000
# Epoch 29/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4140 - acc: 1.0000
# Epoch 30/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.4058 - acc: 1.0000
# Epoch 31/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3973 - acc: 1.0000
# Epoch 32/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3903 - acc: 1.0000
# Epoch 33/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3847 - acc: 1.0000
# Epoch 34/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3785 - acc: 1.0000
# Epoch 35/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3723 - acc: 1.0000
# Epoch 36/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3673 - acc: 1.0000
# Epoch 37/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3702 - acc: 1.0000
# Epoch 38/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3659 - acc: 1.0000
# Epoch 39/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3653 - acc: 1.0000
# Epoch 40/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3748 - acc: 0.9774
# Epoch 41/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3684 - acc: 1.0000
# Epoch 42/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3702 - acc: 0.9850
# Epoch 43/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3558 - acc: 1.0000
# Epoch 44/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3497 - acc: 1.0000
# Epoch 45/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3345 - acc: 1.0000
# Epoch 46/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3402 - acc: 1.0000
# Epoch 47/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3310 - acc: 1.0000
# Epoch 48/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3291 - acc: 1.0000
# Epoch 49/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3245 - acc: 1.0000
# Epoch 50/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3168 - acc: 1.0000
# Epoch 51/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3119 - acc: 1.0000
# Epoch 52/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3110 - acc: 1.0000
# Epoch 53/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3057 - acc: 1.0000
# Epoch 54/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3013 - acc: 1.0000
# Epoch 55/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2979 - acc: 1.0000
# Epoch 56/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2941 - acc: 1.0000
# Epoch 57/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2921 - acc: 1.0000
# Epoch 58/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2887 - acc: 1.0000
# Epoch 59/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2857 - acc: 1.0000
# Epoch 60/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2821 - acc: 1.0000
# Epoch 61/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2791 - acc: 1.0000
# Epoch 62/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2775 - acc: 1.0000
# Epoch 63/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2764 - acc: 1.0000
# Epoch 64/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2748 - acc: 1.0000
# Epoch 65/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2738 - acc: 1.0000
# Epoch 66/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2705 - acc: 1.0000
# Epoch 67/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2654 - acc: 1.0000
# Epoch 68/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2640 - acc: 1.0000
# Epoch 69/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2598 - acc: 1.0000
# Epoch 70/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2559 - acc: 1.0000
# Epoch 71/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2554 - acc: 1.0000
# Epoch 72/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2549 - acc: 1.0000
# Epoch 73/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2552 - acc: 1.0000
# Epoch 74/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2563 - acc: 1.0000
# Epoch 75/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2601 - acc: 1.0000
# Epoch 76/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2601 - acc: 0.9925
# Epoch 77/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2629 - acc: 1.0000
# Epoch 78/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2604 - acc: 1.0000
# Epoch 79/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2501 - acc: 1.0000
# Epoch 80/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2515 - acc: 1.0000
# Epoch 81/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2462 - acc: 1.0000
# Epoch 82/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2511 - acc: 1.0000
# Epoch 83/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2487 - acc: 1.0000
# Epoch 84/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2428 - acc: 0.9925
# Epoch 85/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2456 - acc: 1.0000
# Epoch 86/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2523 - acc: 0.9925
# Epoch 87/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2495 - acc: 0.9925
# Epoch 88/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2597 - acc: 0.9925
# Epoch 89/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2361 - acc: 1.0000
# Epoch 90/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2362 - acc: 1.0000
# Epoch 91/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2398 - acc: 1.0000
# Epoch 92/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2366 - acc: 1.0000
# Epoch 93/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2293 - acc: 1.0000
# Epoch 94/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2263 - acc: 1.0000
# Epoch 95/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2268 - acc: 1.0000
# Epoch 96/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2257 - acc: 1.0000
# Epoch 97/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2216 - acc: 1.0000
# Epoch 98/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2178 - acc: 1.0000
# Epoch 99/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2184 - acc: 1.0000
# Epoch 100/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2188 - acc: 1.0000
# Epoch 101/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2160 - acc: 1.0000
# Epoch 102/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2150 - acc: 1.0000
# Epoch 103/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2114 - acc: 1.0000
# Epoch 104/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2129 - acc: 1.0000
# Epoch 105/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2147 - acc: 1.0000
# Epoch 106/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2090 - acc: 1.0000
# Epoch 107/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2056 - acc: 1.0000
# Epoch 108/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2082 - acc: 1.0000
# Epoch 109/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2101 - acc: 1.0000
# Epoch 110/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2125 - acc: 1.0000
# Epoch 111/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2078 - acc: 1.0000
# Epoch 112/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1966 - acc: 1.0000
# Epoch 113/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1988 - acc: 1.0000
# Epoch 114/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2002 - acc: 1.0000
# Epoch 115/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1950 - acc: 1.0000
# Epoch 116/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1940 - acc: 1.0000
# Epoch 117/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1924 - acc: 1.0000
# Epoch 118/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1922 - acc: 1.0000
# Epoch 119/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1899 - acc: 1.0000
# Epoch 120/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1880 - acc: 1.0000
# Epoch 121/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1895 - acc: 1.0000
# Epoch 122/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1856 - acc: 1.0000
# Epoch 123/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1864 - acc: 1.0000
# Epoch 124/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1835 - acc: 1.0000
# Epoch 125/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1854 - acc: 1.0000
# Epoch 126/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1871 - acc: 1.0000
# Epoch 127/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1898 - acc: 1.0000
# Epoch 128/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1950 - acc: 1.0000
# Epoch 129/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1858 - acc: 1.0000
# Epoch 130/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1927 - acc: 1.0000
# Epoch 131/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2033 - acc: 1.0000
# Epoch 132/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1979 - acc: 0.9925
# Epoch 133/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1926 - acc: 1.0000
# Epoch 134/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1874 - acc: 1.0000
# Epoch 135/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1935 - acc: 1.0000
# Epoch 136/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1987 - acc: 0.9925
# Epoch 137/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1925 - acc: 1.0000
# Epoch 138/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1961 - acc: 0.9850
# Epoch 139/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1922 - acc: 1.0000
# Epoch 140/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1963 - acc: 0.9925
# Epoch 141/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1915 - acc: 1.0000
# Epoch 142/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1872 - acc: 1.0000
# Epoch 143/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1792 - acc: 1.0000
# Epoch 144/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1891 - acc: 1.0000
# Epoch 145/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1815 - acc: 1.0000
# Epoch 146/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1886 - acc: 1.0000
# Epoch 147/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1926 - acc: 1.0000
# Epoch 148/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2115 - acc: 0.9925
# Epoch 149/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2097 - acc: 0.9925
# Epoch 150/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2038 - acc: 1.0000
# Epoch 151/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2168 - acc: 0.9850
# Epoch 152/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2058 - acc: 1.0000
# Epoch 153/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2206 - acc: 0.9699
# Epoch 154/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2138 - acc: 0.9850
# Epoch 155/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1881 - acc: 0.9925
# Epoch 156/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2018 - acc: 1.0000
# Epoch 157/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2034 - acc: 0.9925
# Epoch 158/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2197 - acc: 0.9774
# Epoch 159/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1876 - acc: 1.0000
# Epoch 160/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2111 - acc: 0.9774
# Epoch 161/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2325 - acc: 0.9699
# Epoch 162/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2295 - acc: 0.9774
# Epoch 163/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2001 - acc: 0.9925
# Epoch 164/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2356 - acc: 0.9850
# Epoch 165/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2747 - acc: 0.9850
# Epoch 166/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2474 - acc: 0.9774
# Epoch 167/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2604 - acc: 0.9624
# Epoch 168/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2610 - acc: 0.9699
# Epoch 169/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2839 - acc: 0.9624
# Epoch 170/200
# 133/133 [==============================] - 2s 13ms/sample - loss: 0.2261 - acc: 0.9850
# Epoch 171/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2897 - acc: 0.9699
# Epoch 172/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2184 - acc: 0.9925
# Epoch 173/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3170 - acc: 0.9474
# Epoch 174/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2242 - acc: 1.0000
# Epoch 175/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.3198 - acc: 0.9474
# Epoch 176/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2458 - acc: 0.9774
# Epoch 177/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2890 - acc: 0.9323
# Epoch 178/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2181 - acc: 0.9925
# Epoch 179/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2970 - acc: 0.9699
# Epoch 180/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2081 - acc: 1.0000
# Epoch 181/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2514 - acc: 0.9774
# Epoch 182/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2355 - acc: 0.9850
# Epoch 183/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2101 - acc: 1.0000
# Epoch 184/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2457 - acc: 1.0000
# Epoch 185/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2054 - acc: 1.0000
# Epoch 186/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2212 - acc: 0.9925
# Epoch 187/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2186 - acc: 0.9925
# Epoch 188/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2005 - acc: 1.0000
# Epoch 189/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2240 - acc: 1.0000
# Epoch 190/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1959 - acc: 1.0000
# Epoch 191/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2068 - acc: 1.0000
# Epoch 192/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2083 - acc: 1.0000
# Epoch 193/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1902 - acc: 1.0000
# Epoch 194/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2127 - acc: 1.0000
# Epoch 195/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1912 - acc: 1.0000
# Epoch 196/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1899 - acc: 1.0000
# Epoch 197/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.2019 - acc: 1.0000
# Epoch 198/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1817 - acc: 1.0000
# Epoch 199/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1924 - acc: 1.0000
# Epoch 200/200
# 133/133 [==============================] - 2s 12ms/sample - loss: 0.1861 - acc: 1.0000

# %%
score = model.evaluate(test_images, test_labels, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 1.2222623006621403
# Test accuracy: 0.6865672
